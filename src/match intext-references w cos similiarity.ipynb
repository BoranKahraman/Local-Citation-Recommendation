# %%
import os
import PyPDF2
import re

# Define the citation patterns
citation_patterns = {
    'paranthesis':r'\(\w+ [ve]+ \w+, \d+:\s\d+\)',
    'date_only': r'\(\d{4}\)',
    'APA': r'\(\w+,\s\d{4}\)',
    'APA-Page': r'\(\w+(\s\w+)+,\s\d{4},\s?p\.\s\d+\)',
    'MLA': r'\(\w+\s\d+\)',
    'MLA-Page': r'\(\w+\s\d+,\s?p\.\s\d+\)',
    'Chicago Author-Year': r'\(\w+\s\d{4}\)',
    'Chicago Author-Year-Page': r'\(\w+(\s\w+)+\s\d{4},\s\d+\)',
    'IEEE Numeric': r'\[\d+\]',
    'IEEE-Text': r'\[\d+,\s"[\w\s]+"[,.]?\]',
    'Harvard Author-Year': r'\(\w+\s\d{4}\)',
    'Harvard-Text': r'\(\w+\s\d{4},\s"[\w\s]+"[,.]?\)',
    'Vancouver Numeric': r'\[\d+\]',
    'AMA': r'\[\d+\]',
    'ACS': r'\[\d+\]',
    'CSE': r'\[\d+\]',
    'Bluebook': r'\(\w+\s\d+\)',
    'ASA': r'\(\w+\s\d+\)',
    'AIP': r'\[\d+\]',
    'ISO 690 Numeric': r'\[\d+\]',
    'GSA Style': r'\(\w+\s\d{4}\)',
    'Turabian Style': r'\(\w+\s\d{4}\)',
    'Legal Bluebook': r'\(\w+\s\d+\)',
    'Vancouver Superscript': r'\[\d+\]',
    'Bluebook Law Review': r'\(\w+\s\d+\)',
    'APA Parenthetical': r'\(\w+,\s\d{4}\)',
    'ASA Parenthetical': r'\(\w+\s\d+\)',
    'CMS Author-Date': r'\(\w+\s\d{4}\)',
    'Custom': r'\w+(\sve\s\w+)?\s\(\d{4}:\s\d+-\d+\)',
    'Legal Citations with Statutes': r'\(\w+\s\d+\)',
    'Legal Citations with Court Cases': r'\(\w+\s\d+\)',
    'ISO 690-2 Numeric': r'\[\d+\]',
    'ISO 690-2 Author-Date': r'\(\w+\s\d{4}\)',
    #'APA Parenthetical': r'\(\w+,\s\d{4}\)',
    'ASA Parenthetical': r'\(\w+\s\d+\)',
    'CMS Author-Date': r'\(\w+\s\d{4}\)',
    'Legal Citations with Statutes': r'\(\w+\s\d+\)',
    'Legal Citations with Court Cases': r'\(\w+\s\d+\)',
    'ISO 690-2 Numeric': r'\[\d+\]',
    'ISO 690-2 Author-Date': r'\(\w+\s\d{4}\)',
    'APA (American Psychological Association)': r'\(\w+\s&\s\w+,\s\d{4}\)',
    'APA-Three or More Authors': r'\(\w+\set\sal\.,\s\d{4}\)',
    'APA-Group Author with Abbreviation': r'\(World Health Organization\s\[WHO\],\s\d{4}\)',
    'APA-Direct Quote': r'\(\w+’s\sLast\sName,\s\d{4},\sp\.\sPage\sNumber\)',
    'APA-Secondary Source': r'\(Primary\sAuthor’s\sLast\sName,\sas\scited\sin\sSecondary\sAuthor’s\sLast\sName,\s\d{4}\)',
    'APA-Multiple Works by the Same Author in the Same Year': r'\(\w+’s\sLast\sName,\s\d{4}a\)',
    'APA-Personal Communication': r'\(P\.\s\w+,\spersonal\scommunication,\s\w+\s\d{1,2},\s\d{4}\)',
    'APA-Citing a Source Within a Source': r'\(\w+’s\sLast\sName,\sas\scited\sin\sSecondary\sAuthor’s\sLast\sName,\s\d{4}\)'
}

# Combine the regex patterns into a list
regex_patterns = list(citation_patterns.values())

class Pdf2Text(object):

    def __int__(self):
        pass

    def pdf2txt(self, pdf_path):
        text = ""

        # Open the PDF file in read-binary mode
        with open(pdf_path, 'rb') as pdf_file:
            pdf_reader = PyPDF2.PdfReader(pdf_file)

            # Iterate through each page in the PDF
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()

        return text

    def pdfs2txt(self, directory_path):
        # Initialize an empty list to store the text from each PDF
        text_list = []

        # Iterate through the files in the directory
        for filename in os.listdir(directory_path):
            if filename.endswith(".pdf"):
                # Construct the full path to the PDF file
                pdf_file_path = os.path.join(directory_path, filename)

                # Open the PDF file in read-binary mode
                with open(pdf_file_path, 'rb') as pdf_file:
                    pdf_reader = PyPDF2.PdfReader(pdf_file)

                    # Initialize text for the current PDF
                    pdf_text = ""

                    # Iterate through each page in the PDF
                    for page_num in range(len(pdf_reader.pages)):
                        page = pdf_reader.pages[page_num]
                        pdf_text += page.extract_text()

                    # Append the extracted text to the list
                    text_list.append(pdf_text)

        return text_list


class CitationExtractor(object):

    def __int__(self):
        pass

    def extractCitationSingleDocument(self, text, style):

        pairs = {
            'paranthesis': [],
            'date_only': [],
            'APA': [],
            'APA-Page': [],
            'MLA': [],
            'MLA-Page':[],
            'Chicago Author-Year':[],
            'Chicago Author-Year-Page': [],
            'IEEE Numeric': [],
            'IEEE-Text': [],
            'Harvard Author-Year': [],
            'Harvard-Text': [],
            'Vancouver Numeric': [],
            'AMA': [],
            'ACS': [],
            'CSE': [],
            'Bluebook': [],
            'ASA': [],
            'AIP': [],
            'ISO 690 Numeric': [],
            'GSA Style': [],
            'Turabian Style': [],
            'Legal Bluebook': [],
            'Vancouver Superscript': [],
            'Bluebook Law Review': [],
            #'APA Parenthetical': [],
            'ASA Parenthetical': [],
            'CMS Author-Date': [],
            'Custom': [],
            'Legal Citations with Statutes':[],
            'Legal Citations with Court Cases': [],
            'ISO 690-2 Numeric': [],
            'ISO 690-2 Author-Date': [],
            'APA Parenthetical': [],
            'ASA Parenthetical': [],
            'CMS Author-Date': [],
            'Legal Citations with Statutes': [],
            'Legal Citations with Court Cases': [],
            'ISO 690-2 Numeric':[],
            'ISO 690-2 Author-Date': [],
            'APA (American Psychological Association)': r'\(\w+\s&\s\w+,\s\d{4}\)',
            'APA-Three or More Authors': [],
            'APA-Group Author with Abbreviation': [],
            'APA-Direct Quote': [],
            'APA-Secondary Source': [],
            'APA-Multiple Works by the Same Author in the Same Year': [],
            'APA-Personal Communication': [],
            'APA-Citing a Source Within a Source': []
        }

        sentences = re.split(r'(?<=[.!?])\s+', text)

        if style == "all":
            for sentence in sentences:
                for pattern_name, pattern in citation_patterns.items():
                    matches = re.findall(pattern, sentence)
                    if matches:
                        pairs[pattern_name].append(sentence)

            return pairs

        for sentence in sentences:
                matches = re.findall(citation_patterns[style], sentence)
                if matches:
                    pairs[style].append(sentence)

        return pairs

# %%
extractor = CitationExtractor()
pdf2txt = Pdf2Text()

# %%
path = "10.25064-mulkiye.1050139-2163743.pdf"

# %%
txt = pdf2txt.pdf2txt(path)

# %%
kaynakca = str(txt.split("Kaynakça")[1])

# %%
kaynakca
# Out:
# '\nAoudé I G (2013). Egypt: Revolutionary Process and Global Capitalist Crisis. Arab Studies \nQuarterly, Özel Sayı: Perspectives on the Arab Uprisings , 35(3), 241-254.\nArı T (2012). Geçmişten Günümüze Ortadoğu, Siyaset, Savaş ve Diplomasi . Bursa: MKM \nYayıncılık.\nBBC Türkçe (02/02/2018). İran’da ‘başörtüsünü çıkarma’ eylemleri: 29 kadın gözaltında. \nSon erişim tarihi, 01.05.2020.\nBekaroğlu E A ve Kurt V (2015). Mısır’da Otoriter Rejimin Sürekliliği ve Ordu: ‘Arap \nBaharı’ ve Sonrası Sürecin Analizi. Türkiye Ortadoğu Çalışmaları Dergisi, 2(2), 1-36.\nBehçet M (2019). İkinci Dünya Savaşı Sonrası Mısır’ın Siyasi Tarihi Üzerinden Arap \nBaharı’nın İncelenmesi. Trakya Üniversitesi Sosyal Bilimler Dergisi , 21, 303-321.613\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Bohstedt J (2014). Food Riots and the Politics of Provisions in World History. Institute of \nDevelopment Studies , 444, 1-31.\nBrecher J vd. (2002). Aşağıdan Küreselleşme . Çev. A Yıldırım vd., İstanbul: Aram Yayınları.\nBush R (2010). Food Riots: Poverty, Power and Protest. Journal of Agrarian Change , \n10(1), 119-129.\nCalhoun C (1993). ‘New Social Movements’ of the Early Nineteenth Century. Social \nScience History , 17(3), 385-427. \nCastells M (1997). The Power of Identity, The Information Age: Economy, Society and \nCulture .  Vol 2, Oxford: Wiley-Blackwell, First Edition.\nCastells M (2001). The Internet Galaxy . New York: Oxford University Press.\nCastells M (2013). İsyan ve Umut Ağları-İnternet Çağında Toplumsal Hareketler. Çev. E \nKılıç, İstanbul: Koç Üniversitesi Yayınları, Birinci Baskı.\nÇetinkaya Y D (2014). Toplumsal Hareketler. İçinde: Ş Kardaş ve A Balcı (der), Uluslararası \nİlişkilere Giri ş. Üçüncü Baskı, İstanbul: Küre Yayınları, 479-486.\nÇolak Ç D (2016). Yeni Toplumsal Hareketlere “Yeni” Niteliği Kazandıran Özellikler \nÜzerine Bir Değerlendirme.  Sosyal  Bilimler Dergisi,  3(6), 529-537.\nDede A (2018). Talepkâr Bir Hareket Olarak Yeni Toplumsal Hareketler. Uluslararası \nSosyal Bilimler Dergisi,  2(13), 48-66.\nDehghan S K (2018). Second woman arrested in Tehran for hijab protest. The  \nGuardian , 29 Ocak. Son erişim tarihi, 01/05/2020.\nDeutsche Welle (29/12/2017). İran’da hükümet karşıtı gösteriler devam ediyor. Son \nerişim tarihi, 27/04/2020.\nDeutsche Welle (01/02/2018). İranlı kadınların başörtüsü eylemi yayılıyor. Son erişim \ntarihi, 01/05/2020.\nDolgun U ve Sütlüoğlu T (2014). Sosyal Medya ve Yeni Toplumsal Hareketler. İçinde: V \nBozkurt (der),  Çağdaş Toplumsal Süreçler . Erzurum: Atatürk Üniversitesi, 1-22.\nEmin A (2017). Mısır Siyasetinde Vefd Partisi (1918-1952). (Basılmamış Yüksek Lisans \nTezi). İstanbul: Fatih Sultan  Mehmet Vakıf Üniversitesi.\nErginbaş E (2020). İran’da Toplumsal Hareketler Bağlamında ‘Öteki Olmak’. İran \nAraştırmaları Merkezi, 21 Nisan. Son erişim tarihi, 27/04/2020.\nFuller G E (2016).  Türkiye ve Arap Baharı.  Çev. M Acar, Ankara: Eksi Kitaplar.\nGerbaudo P (2012). Tweets and Streets: Social Media and Contemporary Activism . \nLondon: Pluto Press. 614\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Gerbaudo P (2014).  Twitler ve Sokaklar . Çev. O Akınhay, İstanbul: Agora Kitaplığı.\nGiddens A (2006). Sociology . Cambridge: Polity Press, Fifth Edition.\nGürakar H. T (2012). Bir Toplumsal Hareketin Anatomisi: İran Yeşil Hareketi. İçinde: B \nAdıbelli (der), Doğu-Batı Yol Ayrımında İran.  İstanbul: Bilim+Gönül Yayınları.\nHoffman B (2007-2008). İnternetten Demokrasi İndirmek? İnternetin Latin Amerika’da \nVatandaşlık Haklarını İlerletme Potansiyeli ve Sınırlamaları. Uluslararası İlişkiler,  4(16), \n97-113.\nJohnston H vd. (1994). Identities, Grievances and New Social Movements. İçinde: Hank \nJohnston vd. (der), New Social Movements: From Ideology to Identity. Philadelphia: \n ...

# %%
kaynakca = kaynakca.split(" \n")

# %%
kaynakca
# Out:
# ['\nAoudé I G (2013). Egypt: Revolutionary Process and Global Capitalist Crisis. Arab Studies',
#  'Quarterly, Özel Sayı: Perspectives on the Arab Uprisings , 35(3), 241-254.\nArı T (2012). Geçmişten Günümüze Ortadoğu, Siyaset, Savaş ve Diplomasi . Bursa: MKM',
#  'Yayıncılık.\nBBC Türkçe (02/02/2018). İran’da ‘başörtüsünü çıkarma’ eylemleri: 29 kadın gözaltında.',
#  'Son erişim tarihi, 01.05.2020.\nBekaroğlu E A ve Kurt V (2015). Mısır’da Otoriter Rejimin Sürekliliği ve Ordu: ‘Arap',
#  'Baharı’ ve Sonrası Sürecin Analizi. Türkiye Ortadoğu Çalışmaları Dergisi, 2(2), 1-36.\nBehçet M (2019). İkinci Dünya Savaşı Sonrası Mısır’ın Siyasi Tarihi Üzerinden Arap',
#  'Baharı’nın İncelenmesi. Trakya Üniversitesi Sosyal Bilimler Dergisi , 21, 303-321.613\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin',
#  'İncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Bohstedt J (2014). Food Riots and the Politics of Provisions in World History. Institute of',
#  'Development Studies , 444, 1-31.\nBrecher J vd. (2002). Aşağıdan Küreselleşme . Çev. A Yıldırım vd., İstanbul: Aram Yayınları.\nBush R (2010). Food Riots: Poverty, Power and Protest. Journal of Agrarian Change ,',
#  '10(1), 119-129.\nCalhoun C (1993). ‘New Social Movements’ of the Early Nineteenth Century. Social',
#  'Science History , 17(3), 385-427.',
#  'Castells M (1997). The Power of Identity, The Information Age: Economy, Society and',
#  'Culture .  Vol 2, Oxford: Wiley-Blackwell, First Edition.\nCastells M (2001). The Internet Galaxy . New York: Oxford University Press.\nCastells M (2013). İsyan ve Umut Ağları-İnternet Çağında Toplumsal Hareketler. Çev. E',
#  'Kılıç, İstanbul: Koç Üniversitesi Yayınları, Birinci Baskı.\nÇetinkaya Y D (2014). Toplumsal Hareketler. İçinde: Ş Kardaş ve A Balcı (der), Uluslararası',
#  'İlişkilere Giri ş. Üçüncü Baskı, İstanbul: Küre Yayınları, 479-486.\nÇolak Ç D (2016). Yeni Toplumsal Hareketlere “Yeni” Niteliği Kazandıran Özellikler',
#  'Üzerine Bir Değerlendirme.  Sosyal  Bilimler Dergisi,  3(6), 529-537.\nDede A (2018). Talepkâr Bir Hareket Olarak Yeni Toplumsal Hareketler. Uluslararası',
#  'Sosyal Bilimler Dergisi,  2(13), 48-66.\nDehghan S K (2018). Second woman arrested in Tehran for hijab protest. The ',
#  'Guardian , 29 Ocak. Son erişim tarihi, 01/05/2020.\nDeutsche Welle (29/12/2017). İran’da hükümet karşıtı gösteriler devam ediyor. Son',
#  'erişim tarihi, 27/04/2020.\nDeutsche Welle (01/02/2018). İranlı kadınların başörtüsü eylemi yayılıyor. Son erişim',
#  'tarihi, 01/05/2020.\nDolgun U ve Sütlüoğlu T (2014). Sosyal Medya ve Yeni Toplumsal Hareketler. İçinde: V',
#  'Bozkurt (der),  Çağdaş Toplumsal Süreçler . Erzurum: Atatürk Üniversitesi, 1-22.\nEmin A (2017). Mısır Siyasetinde Vefd Partisi (1918-1952). (Basılmamış Yüksek Lisans',
#  'Tezi). İstanbul: Fatih Sultan  Mehmet Vakıf Üniversitesi.\nErginbaş E (2020). İran’da Toplumsal Hareketler Bağlamında ‘Öteki Olmak’. İran',
#  'Araştırmaları Merkezi, 21 Nisan. Son erişim tarihi, 27/04/2020.\nFuller G E (2016).  Türkiye ve Arap Baharı.  Çev. M Acar, Ankara: Eksi Kitaplar.\nGerbaudo P (2012). Tweets and Streets: Social Media and Contemporary Activism .',
#  'London: Pluto Press. 614\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin',
#  'İncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Gerbaudo P (2014).  Twitler ve Sokaklar . Çev. O Akınhay, İstanbul: Agora Kitaplığı.\nGiddens A (2006). Sociology . Cambridge: Polity Press, Fifth Edition.\nGürakar H. T (2012). Bir Toplumsal Hareketin Anatomisi: İran Yeşil Hareketi. İçinde: B',
#  'Adıbelli (der), Doğu-Batı Yol Ayrımında İran.  İstanbul: Bilim+Gönül Yayınları.\nHoffman B (2007-2008). İnternetten Demokrasi İndirmek? İnternetin Latin Amerika’da',
#  'Vatandaşlık Haklarını İlerletme Potansiyeli ve Sınırlamaları. Uluslararası İlişkiler,  4(16),',
#  '97-113.\nJohnston H vd. (1994). Identities, Grievances and New Social Movements. İçinde: Hank',
#  'Johnston vd. (der), New Social Movements: From Ideology to Identity. Philadelphia:',
#  'Temple University Press, 3-35.\nKamacı Y (2013). 2009’dan 2013’e Yeşil Hareket’in Yolculuğu. Uluslararası Politika',
#  'Akademisi, 1 Temmuz. Son erişim tarihi, 27/04/2020.',
#  'Karabağ G (2018). İran’da başörtüsü mecburiyetine karşı “Beyaz Çarşamba” direnişleri',
#  'devam ediyor. Medyascope , 30 Ocak. Son erişim tarihi: 01/05/2020.',
#  'Karagöz K. (2013). Yeni Medya Çağında Dönüşen Toplumsal Hareketler ve Dijital',
#  'Aktivizm Hareketleri. İletişim ve Diplomasi, 1(1), 131-156.\nKoç M (2017). İran’da Üniversiteler ve Siyaset. İran Araştırmaları Merkezi,  13 Kasım.',
#  'Son erişim tarihi, 28/04/2020.',
#  'Küçükşahin E (2018). Politik Bir Fenomen Olarak Ekmek: 2008 Mısır’ında Ekmek İsyanı.',
#  'Contemporary Research in Economics and Social Sciences , 2(2), 317-347.\nLaclau E ve Mouffe C (2001). Hegemony and Socialist Strategy: Towards a Radical',
#  'Democratic Politics.  London, New  York: Verso, Second Edition.\nLomas N (2018). Telegram and Instagram being restricted in Iran.  Techcrunch,  2 Ocak.',
#  'Son erişim tarihi, 28/04/2020.',
#  'Marshall G (1999). Sosyoloji Sözlüğü . Çev. O Akınhay ve D Kömürcü, Ankara: Bilim ve',
#  'Sanat Yayınları.\nMelucci A (2016). Çağdaş Hareketlerin Sembolik Meydan Okuması. İçinde: K Çayır (der),',
#  'Yeni Sosyal Hareketler-Teorik Açılımlar.  İstanbul: Kaknüs Yayınları, 75-100.\nMossallam A (2013). ’These are Liberated Territories’ – Everyday Resistance in',
#  'Egypt: Dismantling State Power,  Experimenting with Alternatives and the Growing',
#  'Movement From 2000 to 2010. İçinde:  Larbi Sadiki vd. (der), Democratic Transition in',
#  'the Middle East: Unmaking Power . London: Routledge, 109-137.615\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin',
#  'İncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Offe C (2016). Yeni Sosyal Hareketler: Kurumsal Politikanın Sınırlarının Zorlanması.',
#  'İçinde: K Çayır (der), Yeni Sosyal Hareketler-Teorik Açılımlar.  İstanbul: Kaknüs Yayınları,',
#  '47-73.\nÖzkoç Ö (2015). ‘Devrim’in Başladığı Yer: Sidi Bu Zeyd/Tunus. Mülkiye Dergisi , 39(2),',
#  '283-290.\nPapic M ve Noonan S (2011). Sosyal Medya: Bir Protesto Aracı. Çev. E Dündar, Türk',
#  'Kütüphaneciliği, 25(1), 165-172.\nSabah (12/07/1999). Tabular yıkıldı. Son erişim tarihi, 28/04/2020.',
#  'Sadiki L (2000). Popular Uprisings and Arab Democratization. International Journal of',
#  'Middle East Studies , 32(1),  71-95.\nSalamey I (2015). Post-Arab Spring: Changes and Challenges. Third World Quarterly,',
#  '36(1), 111-129.\nSaleh H (2008). Food price crisis bites in Egypt. BBC,  3 Mayıs. Son erişim tarihi,',
#  '26/04/2020.\nSayın Y (2016). Arap Baharı Süreci ve Sömürgelerin Çözülmesi. KMÜ Sosyal ve Ekonomik',
#  'Araştırmalar Dergisi,  18(30),  65-70.\nSayın A (2018). İran’daki gösterilerin anatomisi. Star Açık Görüş,  6 Ocak. Erişim',
#  '01.05.2020.\nScott A (1990). Ideology and The New Social Movements.  London: Unwin Hyman.\nSinkaya B vd. (2018). İran’da Toplumsal Hareketler ve Etkileri. Göç Politikaları Merkezi ,',
#  'Göç Panelleri Serisi.\nŞen G (2012). İran ve ‘Arap Baharı’: Bağlam, Söylem ve Siyaset. Ortadoğu Etütleri,  3(2),',
#  '95-118.\nŞener G (2006). Küresel Kapitalizmin Yeni Kamusal Alanı Olarak İnternet: Yeni Toplumsal',
#  'Hareketlerin İnterneti Kullanımı. (Basılmamış Doktora Tezi). İstanbul: Marmara',
#  'Üniversitesi.\nTafiş A (2013). İran’daki Yeşil Hareket: Gerçeği ve akıbeti. Aljazeera Türk , 30 Aralık. Son',
#  'erişim tarihi, 27/04/2020.\nTarrow S G. (2011). Power in Movement: Social Movements and Contentious Politics.',
#  'Cambridge University Press, Third Edition.\nTatar T (2013). Yeni Toplumsal Hareketler ve Küresel Projeler. Ortadoğu Analiz , 5(57),',
#  '10-19.616\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin',
#  'İncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Tilly C (2004). Social Movements 1768-2004.  London: Paradigm Publishers.\nTilly C (2008). T oplumsal Hareketler . Çev. O Düz, İstanbul: Babil Yayınları.\nTopal Demiroğlu E (2014). Yeni Toplumsal Hareketler: Bir Literatür Taraması. Marmara',
#  'Üniversitesi Siyasal Bilimler Dergisi , 2(1), 133-144.\nTür Ö (2009). Mısır’da Ekonomik Kalkınma Çabaları.  İstanbul Üniversitesi Siyasal Bilgiler',
#  'Fakültesi Dergisi,  41, 183-194.\nTürkdoğan O (1997). Sosyal Hareketlerin Sosyolojisi. İstanbul: Birleşik Yayıncılık.\nUygur H (2017). İran’daki Protesto Gösterileri ve Sloganlar Ne Anlama Geliyor?.  İran',
#  'Araştırmaları Merkezi, 30 Aralık. Son erişim tarihi, 28/04/2020.\nYanık C ve Öztürk M (2014). Toplumsal Hareketlerin Dönüşümü Üzerine Bir',
#  'Değerlendirme. Mukaddime,  5(1), 45-63.\nYouTube (11/02/2011). CNN: Egyptian activist, Wael Ghonim ‘Facebook to thank for',
#  'freedom’. Son erişim tarihi,  24/04/2020.\nYücesoy T ve Karabulut B (2019). Gündem Belirleme Kuramı Odağında İran Yeşil',
#  'Devrimine Bakış: Tweetler Üzerinden Bir Analiz. Karadeniz İletişim Araştırmaları Dergisi ,',
#  '9(2), 22-47.']

# %%
len(kaynakca)
# Out:
# 71

# %%
intext = extractor.extractCitationSingleDocument( txt, "all")

# %%
len(intext)
# Out:
# 41

# %%
intext
# Out:
# {'paranthesis': ['“Toplumsal hareketler, kitlesel bir arka \nplana sahip, sisteme ve kurulu düzene yönelik siyasi ve ekonomik içerikli \nhareketlerdir.” (Yanık ve Öztürk, 2014: 52).',
#   'Yine \naynı şekilde 2013 yılında Türkiye’de başlayan Gezi Parkı protestoları da sosyal \nmedya aracılığıyla yayılmıştır (Dolgun ve Sütlüoğlu, 2014: 8).',
#   'Batılı \nülkelerle kurulan ilişkiler vasıtasıyla Mısır’da otoriter yönetimler iktidarlarını \nkoruyabilmişlerdir (Bekaroğlu ve Kurt, 2015: 3).',
#   'İran’da yaşanan bu olaylar Batılı yayın organları tarafından YouTube ve Twitter \nüzerinden takip edilmiştir (Papic ve Noonan, 2011: 166).',
#   '2 haftaya yakın süre boyunca devam \neden ve Yeşil Hareket’in yeniden filizlenmesi olarak nitelendirilen gösteriler, \nbüyük şehirlerden ziyade daha çok küçük şehirlerde etkisini sürdürmüştür \n(Yücesoy ve Karabulut, 2019: 27).'],
#  'date_only': ['587\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Makale Gönderim Tarihi: 25.08.2020, Makale Kabul Tarihi: 20.05.2021\nAraştırma Makalesi588\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Bu süre zarfında Mısır ve İran’da ortaya çıkmış olan toplumsal hareketler bu 590\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Bu \nsınıflandırmalardan yola çıkılarak toplumsal hareketler; dönüştürücü, reform 591\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Yeni toplumsal hareketler ile kendisinden önceki toplumsal \nhareketler arasındaki temel farklılıklar şu şekilde özetlenebilir; yeni toplumsal 592\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Yeni toplumsal hareketler, ortaya çıktıkları zamana kadar modern \ndönemin devletleri tarafından gündeme alınmamış olan sorunları gündemlerine 593\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   '(7) Yeni toplumsal \nhareket gruplarının örgütlenmesi ve yaygınlaşması geleneksel kanalların 594\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Başlatılmış olan bir protesto ya da eylemin, internet ağları \nüzerinden daha geniş kitlelere ulaştırılması neticesinde toplumsal hareketin \ngördüğü destek artabilmekte, böylelikle protestocular seslerini daha fazla \nduyurabilmekte ve baskı yapma güçleri artmaktadır.595\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   '596\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Dolayısıyla bu durum yaşanan \nbazı toplumsal hareketlerin ülkeden ülkeye farklı motivasyonlarla ortaya \nçıkmasına neden olmuştur.597\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Ülke ekonomisinin çeşitli iç ve dış \nfaktörlerden kaynaklanan kötü durumu ve yönetime gelen kişilerin uyguladığı \npolitikalar neticesinde durumun daha da kötü hale gelmesi, toplumun geçim \nkonusunda sıkıntı yaşaması, yüksek işsizlik oranları ve otoriter rejime karşı \nduyulan memnuniyetsizlik gibi nedenler Mısır’daki toplumsal hareketlerin \nortaya çıkışında etkili olan faktörlerin başında gelmiştir.598\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Nitekim günümüze kadar olan süreçte dış faktörlerin 599\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Sedat döneminde başlayan ve Mübarek döneminde de devam ettirilen IMF \nve Dünya Bankası ile tek taraflı bağımlılık ilişkisi Mısır ekonomisinin sürekli bir 600\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   '2006 ve 2007 yıllarındaki gösteriler nedeniyle elde ettikleri \nkazanımların kendilerine teslim edilmediğini düşünen göstericiler, 6 Nisan günü \niçin Facebook üzerinden bir grev çağrısı yapmışlardır (Bohstedt, 2014: 18).601\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Katılımcıların çeşitli yaş, cinsiyet, \nmeslek, ideolojik aidiyet ve kimlik özellikleri barındırması, hareketin ortaya \nçıkışında ve yayılmasında teknolojinin kullanılması, dile getirilen taleplerin 602\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Siyasi nedenlere bakıldığında; 603\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Yukarıdaki ifadelerde sosyal medya 604\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Yeni toplumsal hareket 605\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Bu gruplar \nanadilde eğitim, kendi dillerini konuşmak gibi dilsel taleplerle, etnik taleplerle \nve kendi bölgelerine yönelik ayrımcılık yapıldığı iddiasıyla toplumsal hareketler \ndüzenlemişlerdir (Sinkaya vd., 2018: 2).606\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Bu iddialara 607\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Gösterilere katılan bireylerin farklı cinsel, etnik, \nideolojik, ekonomik, dinsel kimliklerden gelişi; dile getirilen taleplerin iktidar \namacından ziyade değişim amacı içermesi; internetin gösteriler boyunca aktif 608\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Gösterilerde 2009’daki Yeşil Hareket’in söylemlerine benzer 609\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   '2017 yılının \nsonlarında İranlı kadınlar tarafından Tahran’da başörtüsü protestosu başlatılmış \nve bu protestolar 2018’in ilk aylarından itibaren yeni bir boyut kazanarak farklı 610\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Hareketin ortaya çıkışında etkili olan siyasi bir faktör \nolmaması; toplumsal tabandan gelen özgürlük taleplerinin gösterileri \nşekillendirmesi; harekete destek verenlerin farklı yaş, cinsiyet ve ideoloji \ngruplarına mensup olmaları; gösterilerin iktidar talebi olmadan değişim 611\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Toplumsal düzeyde yıllardır birikmiş \nolan sorunların dışa vurulması için toplumsal hareketlerin organize edilmesinde, 612\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'https://\nwww.bbc.com/turkce/haberler-dunya-42916446 Son erişim tarihi, 01/05/2020\nKaynakça\nAoudé I G (2013).',
#   'Arı T (2012).',
#   'Bekaroğlu E A ve Kurt V (2015).',
#   'Behçet M (2019).',
#   'Trakya Üniversitesi Sosyal Bilimler Dergisi , 21, 303-321.613\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Mülkiye Dergisi , 45(3), 587-616.Bohstedt J (2014).',
#   '(2002).',
#   'Bush R (2010).',
#   'Calhoun C (1993).',
#   'Castells M (1997).',
#   'Castells M (2001).',
#   'Castells M (2013).',
#   'Çetinkaya Y D (2014).',
#   'Çolak Ç D (2016).',
#   'Dede A (2018).',
#   'Dehghan S K (2018).',
#   'Dolgun U ve Sütlüoğlu T (2014).',
#   'Emin A (2017).',
#   'Erginbaş E (2020).',
#   'Fuller G E (2016).',
#   'Gerbaudo P (2012).',
#   '614\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Mülkiye Dergisi , 45(3), 587-616.Gerbaudo P (2014).',
#   'Giddens A (2006).',
#   'T (2012).',
#   '(1994).',
#   'Kamacı Y (2013).',
#   'Karabağ G (2018).',
#   '(2013).',
#   'Koç M (2017).',
#   'Küçükşahin E (2018).',
#   'Laclau E ve Mouffe C (2001).',
#   'Lomas N (2018).',
#   'Marshall G (1999).',
#   'Melucci A (2016).',
#   'Mossallam A (2013).',
#   'London: Routledge, 109-137.615\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Mülkiye Dergisi , 45(3), 587-616.Offe C (2016).',
#   'Özkoç Ö (2015).',
#   'Papic M ve Noonan S (2011).',
#   'Sadiki L (2000).',
#   'Salamey I (2015).',
#   'Saleh H (2008).',
#   'Sayın Y (2016).',
#   'Sayın A (2018).',
#   'Scott A (1990).',
#   '(2018).',
#   'Şen G (2012).',
#   'Şener G (2006).',
#   'Tafiş A (2013).',
#   '(2011).',
#   'Tatar T (2013).',
#   'Ortadoğu Analiz , 5(57), \n10-19.616\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Mülkiye Dergisi , 45(3), 587-616.Tilly C (2004).',
#   'Tilly C (2008).',
#   'Topal Demiroğlu E (2014).',
#   'Tür Ö (2009).',
#   'Türkdoğan O (1997).',
#   'Uygur H (2017).',
#   'Yanık C ve Öztürk M (2014).',
#   'Yücesoy T ve Karabulut B (2019).'],
#  'APA': ['Sübvansiyonlu gıda alan kişilerin listesinde de düzenleme yapılarak \n15 milyon kişi daha listeye eklenmiştir (Saleh, 2008).'],
#  'APA-Page': [],
#  'MLA': [],
#  'MLA-Page': [],
#  'Chicago Author-Year': [],
#  'Chicago Author-Year-Page': [],
#  'IEEE Numeric': [],
#  'IEEE-Text': [],
#  'Harvard Author-Year': [],
#  'Harvard-Text': [],
#  'Vancouver Numeric': [],
#  'AMA': [],
#  'ACS': [],
#  'CSE': [],
#  'Bluebook': [],
#  'ASA': [],
#  'AIP': [],
#  'ISO 690 Numeric': [],
#  'GSA Style': [],
#  'Turabian Style': [],
#  'Legal Bluebook': [],
#  'Vancouver Superscript': [],
#  'Bluebook Law Review': [],
#  'ASA Parenthetical': [],
#  'CMS Author-Date': [],
#  'Custom': ['Tarrow (2011: 8-9) toplumsal hareketlerin 18.',
#   'Toplumsal hareketlerin oluşmasına \ngiden süreç Brecher, Costello ve Smith (2002: 42-43) tarafından; “var olan ve \ngenellikle belirli toplumsal grupları etkileyen toplumsal sorunların zamanla \nbirikmesi ile başlayan ve zaman içinde başkalarının da aynı sorunlara işaret \nettiğinin fark edilmesiyle gelişen bir süreç” şeklinde ifade edilmiştir.',
#   'Gordon Marshall (1999: 746-747), toplumsal hareketleri “dikkate değer sayıdaki \ninsanın, toplumun başlıca özelliklerinden birini ya da birkaçını değiştirmek (ya \nda değiştirilmesine karşı direnmek) için örgütlü çaba harcamaları” şeklinde \ntanımlamıştır.',
#   'Gusfield (1994: 6-8) yeni toplumsal \nhareketlerin karakteristik özelliklerini 8 madde ile özetlemiştir.',
#   'Bölge ülkelerinin 1970’lerden itibaren neo-liberal ekonomiye \ngeçiş hamleleri Tunus ve Mısır başta olmak üzere birçok ülkede görülen ve \nLarbi Sadiki’nin (2000: 79-80) ‘ekmek demokrasisi’1 olarak tanımladığı sistemi \nolumsuz etkilemiş ve Ekmek İsyanlarına giden süreci başlatmıştır.'],
#  'Legal Citations with Statutes': [],
#  'Legal Citations with Court Cases': [],
#  'ISO 690-2 Numeric': [],
#  'ISO 690-2 Author-Date': [],
#  'APA Parenthetical': ['Sübvansiyonlu gıda alan kişilerin listesinde de düzenleme yapılarak \n15 milyon kişi daha listeye eklenmiştir (Saleh, 2008).'],
#  'APA (American Psychological Association)': '\\(\\w+\\s&\\s\\w+,\\s\\d{4}\\)',
#  'APA-Three or More Authors': [],
#  'APA-Group Author with Abbreviation': [],
#  'APA-Direct Quote': [],
#  'APA-Secondary Source': [],
#  'APA-Multiple Works by the Same Author in the Same Year': [],
#  'APA-Personal Communication': [],
#  'APA-Citing a Source Within a Source': []}

# %%
from transformers import AutoModel, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-cased")
model = AutoModel.from_pretrained("dbmdz/bert-base-turkish-cased")

# %%
from sentence_transformers import SentenceTransformer
model2 = SentenceTransformer('emrecan/bert-base-turkish-cased-mean-nli-stsb-tr')
#embeddings = model2.encode(references)

# %%
intext = [v for v in intext.values() if len(v) != 0]

# %%
intext
# Out:
# [['“Toplumsal hareketler, kitlesel bir arka \nplana sahip, sisteme ve kurulu düzene yönelik siyasi ve ekonomik içerikli \nhareketlerdir.” (Yanık ve Öztürk, 2014: 52).',
#   'Yine \naynı şekilde 2013 yılında Türkiye’de başlayan Gezi Parkı protestoları da sosyal \nmedya aracılığıyla yayılmıştır (Dolgun ve Sütlüoğlu, 2014: 8).',
#   'Batılı \nülkelerle kurulan ilişkiler vasıtasıyla Mısır’da otoriter yönetimler iktidarlarını \nkoruyabilmişlerdir (Bekaroğlu ve Kurt, 2015: 3).',
#   'İran’da yaşanan bu olaylar Batılı yayın organları tarafından YouTube ve Twitter \nüzerinden takip edilmiştir (Papic ve Noonan, 2011: 166).',
#   '2 haftaya yakın süre boyunca devam \neden ve Yeşil Hareket’in yeniden filizlenmesi olarak nitelendirilen gösteriler, \nbüyük şehirlerden ziyade daha çok küçük şehirlerde etkisini sürdürmüştür \n(Yücesoy ve Karabulut, 2019: 27).'],
#  ['587\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Makale Gönderim Tarihi: 25.08.2020, Makale Kabul Tarihi: 20.05.2021\nAraştırma Makalesi588\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Bu süre zarfında Mısır ve İran’da ortaya çıkmış olan toplumsal hareketler bu 590\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Bu \nsınıflandırmalardan yola çıkılarak toplumsal hareketler; dönüştürücü, reform 591\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Yeni toplumsal hareketler ile kendisinden önceki toplumsal \nhareketler arasındaki temel farklılıklar şu şekilde özetlenebilir; yeni toplumsal 592\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Yeni toplumsal hareketler, ortaya çıktıkları zamana kadar modern \ndönemin devletleri tarafından gündeme alınmamış olan sorunları gündemlerine 593\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   '(7) Yeni toplumsal \nhareket gruplarının örgütlenmesi ve yaygınlaşması geleneksel kanalların 594\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Başlatılmış olan bir protesto ya da eylemin, internet ağları \nüzerinden daha geniş kitlelere ulaştırılması neticesinde toplumsal hareketin \ngördüğü destek artabilmekte, böylelikle protestocular seslerini daha fazla \nduyurabilmekte ve baskı yapma güçleri artmaktadır.595\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   '596\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Dolayısıyla bu durum yaşanan \nbazı toplumsal hareketlerin ülkeden ülkeye farklı motivasyonlarla ortaya \nçıkmasına neden olmuştur.597\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Ülke ekonomisinin çeşitli iç ve dış \nfaktörlerden kaynaklanan kötü durumu ve yönetime gelen kişilerin uyguladığı \npolitikalar neticesinde durumun daha da kötü hale gelmesi, toplumun geçim \nkonusunda sıkıntı yaşaması, yüksek işsizlik oranları ve otoriter rejime karşı \nduyulan memnuniyetsizlik gibi nedenler Mısır’daki toplumsal hareketlerin \nortaya çıkışında etkili olan faktörlerin başında gelmiştir.598\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Nitekim günümüze kadar olan süreçte dış faktörlerin 599\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Sedat döneminde başlayan ve Mübarek döneminde de devam ettirilen IMF \nve Dünya Bankası ile tek taraflı bağımlılık ilişkisi Mısır ekonomisinin sürekli bir 600\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   '2006 ve 2007 yıllarındaki gösteriler nedeniyle elde ettikleri \nkazanımların kendilerine teslim edilmediğini düşünen göstericiler, 6 Nisan günü \niçin Facebook üzerinden bir grev çağrısı yapmışlardır (Bohstedt, 2014: 18).601\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Katılımcıların çeşitli yaş, cinsiyet, \nmeslek, ideolojik aidiyet ve kimlik özellikleri barındırması, hareketin ortaya \nçıkışında ve yayılmasında teknolojinin kullanılması, dile getirilen taleplerin 602\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Siyasi nedenlere bakıldığında; 603\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Yukarıdaki ifadelerde sosyal medya 604\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Yeni toplumsal hareket 605\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Bu gruplar \nanadilde eğitim, kendi dillerini konuşmak gibi dilsel taleplerle, etnik taleplerle \nve kendi bölgelerine yönelik ayrımcılık yapıldığı iddiasıyla toplumsal hareketler \ndüzenlemişlerdir (Sinkaya vd., 2018: 2).606\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Bu iddialara 607\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Gösterilere katılan bireylerin farklı cinsel, etnik, \nideolojik, ekonomik, dinsel kimliklerden gelişi; dile getirilen taleplerin iktidar \namacından ziyade değişim amacı içermesi; internetin gösteriler boyunca aktif 608\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Gösterilerde 2009’daki Yeşil Hareket’in söylemlerine benzer 609\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   '2017 yılının \nsonlarında İranlı kadınlar tarafından Tahran’da başörtüsü protestosu başlatılmış \nve bu protestolar 2018’in ilk aylarından itibaren yeni bir boyut kazanarak farklı 610\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Hareketin ortaya çıkışında etkili olan siyasi bir faktör \nolmaması; toplumsal tabandan gelen özgürlük taleplerinin gösterileri \nşekillendirmesi; harekete destek verenlerin farklı yaş, cinsiyet ve ideoloji \ngruplarına mensup olmaları; gösterilerin iktidar talebi olmadan değişim 611\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Toplumsal düzeyde yıllardır birikmiş \nolan sorunların dışa vurulması için toplumsal hareketlerin organize edilmesinde, 612\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'https://\nwww.bbc.com/turkce/haberler-dunya-42916446 Son erişim tarihi, 01/05/2020\nKaynakça\nAoudé I G (2013).',
#   'Arı T (2012).',
#   'Bekaroğlu E A ve Kurt V (2015).',
#   'Behçet M (2019).',
#   'Trakya Üniversitesi Sosyal Bilimler Dergisi , 21, 303-321.613\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Mülkiye Dergisi , 45(3), 587-616.Bohstedt J (2014).',
#   '(2002).',
#   'Bush R (2010).',
#   'Calhoun C (1993).',
#   'Castells M (1997).',
#   'Castells M (2001).',
#   'Castells M (2013).',
#   'Çetinkaya Y D (2014).',
#   'Çolak Ç D (2016).',
#   'Dede A (2018).',
#   'Dehghan S K (2018).',
#   'Dolgun U ve Sütlüoğlu T (2014).',
#   'Emin A (2017).',
#   'Erginbaş E (2020).',
#   'Fuller G E (2016).',
#   'Gerbaudo P (2012).',
#   '614\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Mülkiye Dergisi , 45(3), 587-616.Gerbaudo P (2014).',
#   'Giddens A (2006).',
#   'T (2012).',
#   '(1994).',
#   'Kamacı Y (2013).',
#   'Karabağ G (2018).',
#   '(2013).',
#   'Koç M (2017).',
#   'Küçükşahin E (2018).',
#   'Laclau E ve Mouffe C (2001).',
#   'Lomas N (2018).',
#   'Marshall G (1999).',
#   'Melucci A (2016).',
#   'Mossallam A (2013).',
#   'London: Routledge, 109-137.615\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Mülkiye Dergisi , 45(3), 587-616.Offe C (2016).',
#   'Özkoç Ö (2015).',
#   'Papic M ve Noonan S (2011).',
#   'Sadiki L (2000).',
#   'Salamey I (2015).',
#   'Saleh H (2008).',
#   'Sayın Y (2016).',
#   'Sayın A (2018).',
#   'Scott A (1990).',
#   '(2018).',
#   'Şen G (2012).',
#   'Şener G (2006).',
#   'Tafiş A (2013).',
#   '(2011).',
#   'Tatar T (2013).',
#   'Ortadoğu Analiz , 5(57), \n10-19.616\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#   'Mülkiye Dergisi , 45(3), 587-616.Tilly C (2004).',
#   'Tilly C (2008).',
#   'Topal Demiroğlu E (2014).',
#   'Tür Ö (2009).',
#   'Türkdoğan O (1997).',
#   'Uygur H (2017).',
#   'Yanık C ve Öztürk M (2014).',
#   'Yücesoy T ve Karabulut B (2019).'],
#  ['Sübvansiyonlu gıda alan kişilerin listesinde de düzenleme yapılarak \n15 milyon kişi daha listeye eklenmiştir (Saleh, 2008).'],
#  ['Tarrow (2011: 8-9) toplumsal hareketlerin 18.',
#   'Toplumsal hareketlerin oluşmasına \ngiden süreç Brecher, Costello ve Smith (2002: 42-43) tarafından; “var olan ve \ngenellikle belirli toplumsal grupları etkileyen toplumsal sorunların zamanla \nbirikmesi ile başlayan ve zaman içinde başkalarının da aynı sorunlara işaret \nettiğinin fark edilmesiyle gelişen bir süreç” şeklinde ifade edilmiştir.',
#   'Gordon Marshall (1999: 746-747), toplumsal hareketleri “dikkate değer sayıdaki \ninsanın, toplumun başlıca özelliklerinden birini ya da birkaçını değiştirmek (ya \nda değiştirilmesine karşı direnmek) için örgütlü çaba harcamaları” şeklinde \ntanımlamıştır.',
#   'Gusfield (1994: 6-8) yeni toplumsal \nhareketlerin karakteristik özelliklerini 8 madde ile özetlemiştir.',
#   'Bölge ülkelerinin 1970’lerden itibaren neo-liberal ekonomiye \ngeçiş hamleleri Tunus ve Mısır başta olmak üzere birçok ülkede görülen ve \nLarbi Sadiki’nin (2000: 79-80) ‘ekmek demokrasisi’1 olarak tanımladığı sistemi \nolumsuz etkilemiş ve Ekmek İsyanlarına giden süreci başlatmıştır.'],
#  ['Sübvansiyonlu gıda alan kişilerin listesinde de düzenleme yapılarak \n15 milyon kişi daha listeye eklenmiştir (Saleh, 2008).'],
#  '\\(\\w+\\s&\\s\\w+,\\s\\d{4}\\)']

# %%
intext_flattened_list = [item for sublist in intext for item in sublist]

# %%
intext=intext_flattened_list

# %%
intext
# Out:
# ['“Toplumsal hareketler, kitlesel bir arka \nplana sahip, sisteme ve kurulu düzene yönelik siyasi ve ekonomik içerikli \nhareketlerdir.” (Yanık ve Öztürk, 2014: 52).',
#  'Yine \naynı şekilde 2013 yılında Türkiye’de başlayan Gezi Parkı protestoları da sosyal \nmedya aracılığıyla yayılmıştır (Dolgun ve Sütlüoğlu, 2014: 8).',
#  'Batılı \nülkelerle kurulan ilişkiler vasıtasıyla Mısır’da otoriter yönetimler iktidarlarını \nkoruyabilmişlerdir (Bekaroğlu ve Kurt, 2015: 3).',
#  'İran’da yaşanan bu olaylar Batılı yayın organları tarafından YouTube ve Twitter \nüzerinden takip edilmiştir (Papic ve Noonan, 2011: 166).',
#  '2 haftaya yakın süre boyunca devam \neden ve Yeşil Hareket’in yeniden filizlenmesi olarak nitelendirilen gösteriler, \nbüyük şehirlerden ziyade daha çok küçük şehirlerde etkisini sürdürmüştür \n(Yücesoy ve Karabulut, 2019: 27).',
#  '587\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Makale Gönderim Tarihi: 25.08.2020, Makale Kabul Tarihi: 20.05.2021\nAraştırma Makalesi588\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Bu süre zarfında Mısır ve İran’da ortaya çıkmış olan toplumsal hareketler bu 590\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Bu \nsınıflandırmalardan yola çıkılarak toplumsal hareketler; dönüştürücü, reform 591\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Yeni toplumsal hareketler ile kendisinden önceki toplumsal \nhareketler arasındaki temel farklılıklar şu şekilde özetlenebilir; yeni toplumsal 592\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Yeni toplumsal hareketler, ortaya çıktıkları zamana kadar modern \ndönemin devletleri tarafından gündeme alınmamış olan sorunları gündemlerine 593\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  '(7) Yeni toplumsal \nhareket gruplarının örgütlenmesi ve yaygınlaşması geleneksel kanalların 594\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Başlatılmış olan bir protesto ya da eylemin, internet ağları \nüzerinden daha geniş kitlelere ulaştırılması neticesinde toplumsal hareketin \ngördüğü destek artabilmekte, böylelikle protestocular seslerini daha fazla \nduyurabilmekte ve baskı yapma güçleri artmaktadır.595\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  '596\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Dolayısıyla bu durum yaşanan \nbazı toplumsal hareketlerin ülkeden ülkeye farklı motivasyonlarla ortaya \nçıkmasına neden olmuştur.597\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Ülke ekonomisinin çeşitli iç ve dış \nfaktörlerden kaynaklanan kötü durumu ve yönetime gelen kişilerin uyguladığı \npolitikalar neticesinde durumun daha da kötü hale gelmesi, toplumun geçim \nkonusunda sıkıntı yaşaması, yüksek işsizlik oranları ve otoriter rejime karşı \nduyulan memnuniyetsizlik gibi nedenler Mısır’daki toplumsal hareketlerin \nortaya çıkışında etkili olan faktörlerin başında gelmiştir.598\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Nitekim günümüze kadar olan süreçte dış faktörlerin 599\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Sedat döneminde başlayan ve Mübarek döneminde de devam ettirilen IMF \nve Dünya Bankası ile tek taraflı bağımlılık ilişkisi Mısır ekonomisinin sürekli bir 600\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  '2006 ve 2007 yıllarındaki gösteriler nedeniyle elde ettikleri \nkazanımların kendilerine teslim edilmediğini düşünen göstericiler, 6 Nisan günü \niçin Facebook üzerinden bir grev çağrısı yapmışlardır (Bohstedt, 2014: 18).601\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Katılımcıların çeşitli yaş, cinsiyet, \nmeslek, ideolojik aidiyet ve kimlik özellikleri barındırması, hareketin ortaya \nçıkışında ve yayılmasında teknolojinin kullanılması, dile getirilen taleplerin 602\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Siyasi nedenlere bakıldığında; 603\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Yukarıdaki ifadelerde sosyal medya 604\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Yeni toplumsal hareket 605\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Bu gruplar \nanadilde eğitim, kendi dillerini konuşmak gibi dilsel taleplerle, etnik taleplerle \nve kendi bölgelerine yönelik ayrımcılık yapıldığı iddiasıyla toplumsal hareketler \ndüzenlemişlerdir (Sinkaya vd., 2018: 2).606\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Bu iddialara 607\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Gösterilere katılan bireylerin farklı cinsel, etnik, \nideolojik, ekonomik, dinsel kimliklerden gelişi; dile getirilen taleplerin iktidar \namacından ziyade değişim amacı içermesi; internetin gösteriler boyunca aktif 608\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Gösterilerde 2009’daki Yeşil Hareket’in söylemlerine benzer 609\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  '2017 yılının \nsonlarında İranlı kadınlar tarafından Tahran’da başörtüsü protestosu başlatılmış \nve bu protestolar 2018’in ilk aylarından itibaren yeni bir boyut kazanarak farklı 610\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Hareketin ortaya çıkışında etkili olan siyasi bir faktör \nolmaması; toplumsal tabandan gelen özgürlük taleplerinin gösterileri \nşekillendirmesi; harekete destek verenlerin farklı yaş, cinsiyet ve ideoloji \ngruplarına mensup olmaları; gösterilerin iktidar talebi olmadan değişim 611\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Toplumsal düzeyde yıllardır birikmiş \nolan sorunların dışa vurulması için toplumsal hareketlerin organize edilmesinde, 612\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'https://\nwww.bbc.com/turkce/haberler-dunya-42916446 Son erişim tarihi, 01/05/2020\nKaynakça\nAoudé I G (2013).',
#  'Arı T (2012).',
#  'Bekaroğlu E A ve Kurt V (2015).',
#  'Behçet M (2019).',
#  'Trakya Üniversitesi Sosyal Bilimler Dergisi , 21, 303-321.613\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Mülkiye Dergisi , 45(3), 587-616.Bohstedt J (2014).',
#  '(2002).',
#  'Bush R (2010).',
#  'Calhoun C (1993).',
#  'Castells M (1997).',
#  'Castells M (2001).',
#  'Castells M (2013).',
#  'Çetinkaya Y D (2014).',
#  'Çolak Ç D (2016).',
#  'Dede A (2018).',
#  'Dehghan S K (2018).',
#  'Dolgun U ve Sütlüoğlu T (2014).',
#  'Emin A (2017).',
#  'Erginbaş E (2020).',
#  'Fuller G E (2016).',
#  'Gerbaudo P (2012).',
#  '614\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Mülkiye Dergisi , 45(3), 587-616.Gerbaudo P (2014).',
#  'Giddens A (2006).',
#  'T (2012).',
#  '(1994).',
#  'Kamacı Y (2013).',
#  'Karabağ G (2018).',
#  '(2013).',
#  'Koç M (2017).',
#  'Küçükşahin E (2018).',
#  'Laclau E ve Mouffe C (2001).',
#  'Lomas N (2018).',
#  'Marshall G (1999).',
#  'Melucci A (2016).',
#  'Mossallam A (2013).',
#  'London: Routledge, 109-137.615\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Mülkiye Dergisi , 45(3), 587-616.Offe C (2016).',
#  'Özkoç Ö (2015).',
#  'Papic M ve Noonan S (2011).',
#  'Sadiki L (2000).',
#  'Salamey I (2015).',
#  'Saleh H (2008).',
#  'Sayın Y (2016).',
#  'Sayın A (2018).',
#  'Scott A (1990).',
#  '(2018).',
#  'Şen G (2012).',
#  'Şener G (2006).',
#  'Tafiş A (2013).',
#  '(2011).',
#  'Tatar T (2013).',
#  'Ortadoğu Analiz , 5(57), \n10-19.616\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin \nİncelenmesi: Mısır ve İran Örnekleri.',
#  'Mülkiye Dergisi , 45(3), 587-616.Tilly C (2004).',
#  'Tilly C (2008).',
#  'Topal Demiroğlu E (2014).',
#  'Tür Ö (2009).',
#  'Türkdoğan O (1997).',
#  'Uygur H (2017).',
#  'Yanık C ve Öztürk M (2014).',
#  'Yücesoy T ve Karabulut B (2019).',
#  'Sübvansiyonlu gıda alan kişilerin listesinde de düzenleme yapılarak \n15 milyon kişi daha listeye eklenmiştir (Saleh, 2008).',
#  'Tarrow (2011: 8-9) toplumsal hareketlerin 18.',
#  'Toplumsal hareketlerin oluşmasına \ngiden süreç Brecher, Costello ve Smith (2002: 42-43) tarafından; “var olan ve \ngenellikle belirli toplumsal grupları etkileyen toplumsal sorunların zamanla \nbirikmesi ile başlayan ve zaman içinde başkalarının da aynı sorunlara işaret \nettiğinin fark edilmesiyle gelişen bir süreç” şeklinde ifade edilmiştir.',
#  'Gordon Marshall (1999: 746-747), toplumsal hareketleri “dikkate değer sayıdaki \ninsanın, toplumun başlıca özelliklerinden birini ya da birkaçını değiştirmek (ya \nda değiştirilmesine karşı direnmek) için örgütlü çaba harcamaları” şeklinde \ntanımlamıştır.',
#  'Gusfield (1994: 6-8) yeni toplumsal \nhareketlerin karakteristik özelliklerini 8 madde ile özetlemiştir.',
#  'Bölge ülkelerinin 1970’lerden itibaren neo-liberal ekonomiye \ngeçiş hamleleri Tunus ve Mısır başta olmak üzere birçok ülkede görülen ve \nLarbi Sadiki’nin (2000: 79-80) ‘ekmek demokrasisi’1 olarak tanımladığı sistemi \nolumsuz etkilemiş ve Ekmek İsyanlarına giden süreci başlatmıştır.',
#  'Sübvansiyonlu gıda alan kişilerin listesinde de düzenleme yapılarak \n15 milyon kişi daha listeye eklenmiştir (Saleh, 2008).',
#  '\\',
#  '(',
#  '\\',
#  'w',
#  '+',
#  '\\',
#  's',
#  '&',
#  '\\',
#  's',
#  '\\',
#  'w',
#  '+',
#  ',',
#  '\\',
#  's',
#  '\\',
#  'd',
#  '{',
#  '4',
#  '}',
#  '\\',
#  ')']

# %%
kaynakca
# Out:
# ['\nAoudé I G (2013). Egypt: Revolutionary Process and Global Capitalist Crisis. Arab Studies',
#  'Quarterly, Özel Sayı: Perspectives on the Arab Uprisings , 35(3), 241-254.\nArı T (2012). Geçmişten Günümüze Ortadoğu, Siyaset, Savaş ve Diplomasi . Bursa: MKM',
#  'Yayıncılık.\nBBC Türkçe (02/02/2018). İran’da ‘başörtüsünü çıkarma’ eylemleri: 29 kadın gözaltında.',
#  'Son erişim tarihi, 01.05.2020.\nBekaroğlu E A ve Kurt V (2015). Mısır’da Otoriter Rejimin Sürekliliği ve Ordu: ‘Arap',
#  'Baharı’ ve Sonrası Sürecin Analizi. Türkiye Ortadoğu Çalışmaları Dergisi, 2(2), 1-36.\nBehçet M (2019). İkinci Dünya Savaşı Sonrası Mısır’ın Siyasi Tarihi Üzerinden Arap',
#  'Baharı’nın İncelenmesi. Trakya Üniversitesi Sosyal Bilimler Dergisi , 21, 303-321.613\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin',
#  'İncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Bohstedt J (2014). Food Riots and the Politics of Provisions in World History. Institute of',
#  'Development Studies , 444, 1-31.\nBrecher J vd. (2002). Aşağıdan Küreselleşme . Çev. A Yıldırım vd., İstanbul: Aram Yayınları.\nBush R (2010). Food Riots: Poverty, Power and Protest. Journal of Agrarian Change ,',
#  '10(1), 119-129.\nCalhoun C (1993). ‘New Social Movements’ of the Early Nineteenth Century. Social',
#  'Science History , 17(3), 385-427.',
#  'Castells M (1997). The Power of Identity, The Information Age: Economy, Society and',
#  'Culture .  Vol 2, Oxford: Wiley-Blackwell, First Edition.\nCastells M (2001). The Internet Galaxy . New York: Oxford University Press.\nCastells M (2013). İsyan ve Umut Ağları-İnternet Çağında Toplumsal Hareketler. Çev. E',
#  'Kılıç, İstanbul: Koç Üniversitesi Yayınları, Birinci Baskı.\nÇetinkaya Y D (2014). Toplumsal Hareketler. İçinde: Ş Kardaş ve A Balcı (der), Uluslararası',
#  'İlişkilere Giri ş. Üçüncü Baskı, İstanbul: Küre Yayınları, 479-486.\nÇolak Ç D (2016). Yeni Toplumsal Hareketlere “Yeni” Niteliği Kazandıran Özellikler',
#  'Üzerine Bir Değerlendirme.  Sosyal  Bilimler Dergisi,  3(6), 529-537.\nDede A (2018). Talepkâr Bir Hareket Olarak Yeni Toplumsal Hareketler. Uluslararası',
#  'Sosyal Bilimler Dergisi,  2(13), 48-66.\nDehghan S K (2018). Second woman arrested in Tehran for hijab protest. The ',
#  'Guardian , 29 Ocak. Son erişim tarihi, 01/05/2020.\nDeutsche Welle (29/12/2017). İran’da hükümet karşıtı gösteriler devam ediyor. Son',
#  'erişim tarihi, 27/04/2020.\nDeutsche Welle (01/02/2018). İranlı kadınların başörtüsü eylemi yayılıyor. Son erişim',
#  'tarihi, 01/05/2020.\nDolgun U ve Sütlüoğlu T (2014). Sosyal Medya ve Yeni Toplumsal Hareketler. İçinde: V',
#  'Bozkurt (der),  Çağdaş Toplumsal Süreçler . Erzurum: Atatürk Üniversitesi, 1-22.\nEmin A (2017). Mısır Siyasetinde Vefd Partisi (1918-1952). (Basılmamış Yüksek Lisans',
#  'Tezi). İstanbul: Fatih Sultan  Mehmet Vakıf Üniversitesi.\nErginbaş E (2020). İran’da Toplumsal Hareketler Bağlamında ‘Öteki Olmak’. İran',
#  'Araştırmaları Merkezi, 21 Nisan. Son erişim tarihi, 27/04/2020.\nFuller G E (2016).  Türkiye ve Arap Baharı.  Çev. M Acar, Ankara: Eksi Kitaplar.\nGerbaudo P (2012). Tweets and Streets: Social Media and Contemporary Activism .',
#  'London: Pluto Press. 614\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin',
#  'İncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Gerbaudo P (2014).  Twitler ve Sokaklar . Çev. O Akınhay, İstanbul: Agora Kitaplığı.\nGiddens A (2006). Sociology . Cambridge: Polity Press, Fifth Edition.\nGürakar H. T (2012). Bir Toplumsal Hareketin Anatomisi: İran Yeşil Hareketi. İçinde: B',
#  'Adıbelli (der), Doğu-Batı Yol Ayrımında İran.  İstanbul: Bilim+Gönül Yayınları.\nHoffman B (2007-2008). İnternetten Demokrasi İndirmek? İnternetin Latin Amerika’da',
#  'Vatandaşlık Haklarını İlerletme Potansiyeli ve Sınırlamaları. Uluslararası İlişkiler,  4(16),',
#  '97-113.\nJohnston H vd. (1994). Identities, Grievances and New Social Movements. İçinde: Hank',
#  'Johnston vd. (der), New Social Movements: From Ideology to Identity. Philadelphia:',
#  'Temple University Press, 3-35.\nKamacı Y (2013). 2009’dan 2013’e Yeşil Hareket’in Yolculuğu. Uluslararası Politika',
#  'Akademisi, 1 Temmuz. Son erişim tarihi, 27/04/2020.',
#  'Karabağ G (2018). İran’da başörtüsü mecburiyetine karşı “Beyaz Çarşamba” direnişleri',
#  'devam ediyor. Medyascope , 30 Ocak. Son erişim tarihi: 01/05/2020.',
#  'Karagöz K. (2013). Yeni Medya Çağında Dönüşen Toplumsal Hareketler ve Dijital',
#  'Aktivizm Hareketleri. İletişim ve Diplomasi, 1(1), 131-156.\nKoç M (2017). İran’da Üniversiteler ve Siyaset. İran Araştırmaları Merkezi,  13 Kasım.',
#  'Son erişim tarihi, 28/04/2020.',
#  'Küçükşahin E (2018). Politik Bir Fenomen Olarak Ekmek: 2008 Mısır’ında Ekmek İsyanı.',
#  'Contemporary Research in Economics and Social Sciences , 2(2), 317-347.\nLaclau E ve Mouffe C (2001). Hegemony and Socialist Strategy: Towards a Radical',
#  'Democratic Politics.  London, New  York: Verso, Second Edition.\nLomas N (2018). Telegram and Instagram being restricted in Iran.  Techcrunch,  2 Ocak.',
#  'Son erişim tarihi, 28/04/2020.',
#  'Marshall G (1999). Sosyoloji Sözlüğü . Çev. O Akınhay ve D Kömürcü, Ankara: Bilim ve',
#  'Sanat Yayınları.\nMelucci A (2016). Çağdaş Hareketlerin Sembolik Meydan Okuması. İçinde: K Çayır (der),',
#  'Yeni Sosyal Hareketler-Teorik Açılımlar.  İstanbul: Kaknüs Yayınları, 75-100.\nMossallam A (2013). ’These are Liberated Territories’ – Everyday Resistance in',
#  'Egypt: Dismantling State Power,  Experimenting with Alternatives and the Growing',
#  'Movement From 2000 to 2010. İçinde:  Larbi Sadiki vd. (der), Democratic Transition in',
#  'the Middle East: Unmaking Power . London: Routledge, 109-137.615\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin',
#  'İncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Offe C (2016). Yeni Sosyal Hareketler: Kurumsal Politikanın Sınırlarının Zorlanması.',
#  'İçinde: K Çayır (der), Yeni Sosyal Hareketler-Teorik Açılımlar.  İstanbul: Kaknüs Yayınları,',
#  '47-73.\nÖzkoç Ö (2015). ‘Devrim’in Başladığı Yer: Sidi Bu Zeyd/Tunus. Mülkiye Dergisi , 39(2),',
#  '283-290.\nPapic M ve Noonan S (2011). Sosyal Medya: Bir Protesto Aracı. Çev. E Dündar, Türk',
#  'Kütüphaneciliği, 25(1), 165-172.\nSabah (12/07/1999). Tabular yıkıldı. Son erişim tarihi, 28/04/2020.',
#  'Sadiki L (2000). Popular Uprisings and Arab Democratization. International Journal of',
#  'Middle East Studies , 32(1),  71-95.\nSalamey I (2015). Post-Arab Spring: Changes and Challenges. Third World Quarterly,',
#  '36(1), 111-129.\nSaleh H (2008). Food price crisis bites in Egypt. BBC,  3 Mayıs. Son erişim tarihi,',
#  '26/04/2020.\nSayın Y (2016). Arap Baharı Süreci ve Sömürgelerin Çözülmesi. KMÜ Sosyal ve Ekonomik',
#  'Araştırmalar Dergisi,  18(30),  65-70.\nSayın A (2018). İran’daki gösterilerin anatomisi. Star Açık Görüş,  6 Ocak. Erişim',
#  '01.05.2020.\nScott A (1990). Ideology and The New Social Movements.  London: Unwin Hyman.\nSinkaya B vd. (2018). İran’da Toplumsal Hareketler ve Etkileri. Göç Politikaları Merkezi ,',
#  'Göç Panelleri Serisi.\nŞen G (2012). İran ve ‘Arap Baharı’: Bağlam, Söylem ve Siyaset. Ortadoğu Etütleri,  3(2),',
#  '95-118.\nŞener G (2006). Küresel Kapitalizmin Yeni Kamusal Alanı Olarak İnternet: Yeni Toplumsal',
#  'Hareketlerin İnterneti Kullanımı. (Basılmamış Doktora Tezi). İstanbul: Marmara',
#  'Üniversitesi.\nTafiş A (2013). İran’daki Yeşil Hareket: Gerçeği ve akıbeti. Aljazeera Türk , 30 Aralık. Son',
#  'erişim tarihi, 27/04/2020.\nTarrow S G. (2011). Power in Movement: Social Movements and Contentious Politics.',
#  'Cambridge University Press, Third Edition.\nTatar T (2013). Yeni Toplumsal Hareketler ve Küresel Projeler. Ortadoğu Analiz , 5(57),',
#  '10-19.616\nTandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin',
#  'İncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Tilly C (2004). Social Movements 1768-2004.  London: Paradigm Publishers.\nTilly C (2008). T oplumsal Hareketler . Çev. O Düz, İstanbul: Babil Yayınları.\nTopal Demiroğlu E (2014). Yeni Toplumsal Hareketler: Bir Literatür Taraması. Marmara',
#  'Üniversitesi Siyasal Bilimler Dergisi , 2(1), 133-144.\nTür Ö (2009). Mısır’da Ekonomik Kalkınma Çabaları.  İstanbul Üniversitesi Siyasal Bilgiler',
#  'Fakültesi Dergisi,  41, 183-194.\nTürkdoğan O (1997). Sosyal Hareketlerin Sosyolojisi. İstanbul: Birleşik Yayıncılık.\nUygur H (2017). İran’daki Protesto Gösterileri ve Sloganlar Ne Anlama Geliyor?.  İran',
#  'Araştırmaları Merkezi, 30 Aralık. Son erişim tarihi, 28/04/2020.\nYanık C ve Öztürk M (2014). Toplumsal Hareketlerin Dönüşümü Üzerine Bir',
#  'Değerlendirme. Mukaddime,  5(1), 45-63.\nYouTube (11/02/2011). CNN: Egyptian activist, Wael Ghonim ‘Facebook to thank for',
#  'freedom’. Son erişim tarihi,  24/04/2020.\nYücesoy T ve Karabulut B (2019). Gündem Belirleme Kuramı Odağında İran Yeşil',
#  'Devrimine Bakış: Tweetler Üzerinden Bir Analiz. Karadeniz İletişim Araştırmaları Dergisi ,',
#  '9(2), 22-47.']

# %%
embeddings_kaynakca = model2.encode(kaynakca)

# %%
len(embeddings_kaynakca)
# Out:
# 71

# %%
embeddings_intext = model2.encode(intext)

# %%
len(embeddings_intext)
# Out:
# 122

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(embeddings_kaynakca, embeddings_intext)

# Find the best matches
matches = []

for i in range(len(similarity_matrix)):
    best_match_index = np.argmax(similarity_matrix[i])
    best_match_similarity = similarity_matrix[i][best_match_index]
    matches.append((i, best_match_index, best_match_similarity))

# Sort matches by similarity
matches.sort(key=lambda x: x[2], reverse=True)

# Print the matching references
for match in matches:
    reference_ref_idx = match[0]
    reference_idx = match[1]
    similarity = match[2]
    print(f"Reference {reference_ref_idx} matches with Reference Ref {reference_idx} with a cosine similarity of {similarity:.2f}")
    print("\n(kaynakça): ", kaynakca[reference_ref_idx], "\n\n(intext): ",intext[reference_idx])
    print("--------------------------------------------------------")
# Out:
# Reference 22 matches with Reference Ref 52 with a cosine similarity of 0.89
#
# (kaynakça):  London: Pluto Press. 614
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
#
# (intext):  614
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 5 matches with Reference Ref 35 with a cosine similarity of 0.88
#
# (kaynakça):  Baharı’nın İncelenmesi. Trakya Üniversitesi Sosyal Bilimler Dergisi , 21, 303-321.613
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
#
# (intext):  Trakya Üniversitesi Sosyal Bilimler Dergisi , 21, 303-321.613
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 62 matches with Reference Ref 52 with a cosine similarity of 0.86
#
# (kaynakça):  10-19.616
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
#
# (intext):  614
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 44 matches with Reference Ref 67 with a cosine similarity of 0.80
#
# (kaynakça):  the Middle East: Unmaking Power . London: Routledge, 109-137.615
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
#
# (intext):  London: Routledge, 109-137.615
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 48 matches with Reference Ref 70 with a cosine similarity of 0.71
#
# (kaynakça):  283-290.
# Papic M ve Noonan S (2011). Sosyal Medya: Bir Protesto Aracı. Çev. E Dündar, Türk
#
# (intext):  Papic M ve Noonan S (2011).
# --------------------------------------------------------
# Reference 45 matches with Reference Ref 83 with a cosine similarity of 0.69
#
# (kaynakça):  İncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Offe C (2016). Yeni Sosyal Hareketler: Kurumsal Politikanın Sınırlarının Zorlanması.
#
# (intext):  Ortadoğu Analiz , 5(57),
# 10-19.616
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 18 matches with Reference Ref 47 with a cosine similarity of 0.67
#
# (kaynakça):  tarihi, 01/05/2020.
# Dolgun U ve Sütlüoğlu T (2014). Sosyal Medya ve Yeni Toplumsal Hareketler. İçinde: V
#
# (intext):  Dolgun U ve Sütlüoğlu T (2014).
# --------------------------------------------------------
# Reference 23 matches with Reference Ref 53 with a cosine similarity of 0.67
#
# (kaynakça):  İncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Gerbaudo P (2014).  Twitler ve Sokaklar . Çev. O Akınhay, İstanbul: Agora Kitaplığı.
# Giddens A (2006). Sociology . Cambridge: Polity Press, Fifth Edition.
# Gürakar H. T (2012). Bir Toplumsal Hareketin Anatomisi: İran Yeşil Hareketi. İçinde: B
#
# (intext):  Mülkiye Dergisi , 45(3), 587-616.Gerbaudo P (2014).
# --------------------------------------------------------
# Reference 63 matches with Reference Ref 67 with a cosine similarity of 0.66
#
# (kaynakça):  İncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Tilly C (2004). Social Movements 1768-2004.  London: Paradigm Publishers.
# Tilly C (2008). T oplumsal Hareketler . Çev. O Düz, İstanbul: Babil Yayınları.
# Topal Demiroğlu E (2014). Yeni Toplumsal Hareketler: Bir Literatür Taraması. Marmara
#
# (intext):  London: Routledge, 109-137.615
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 4 matches with Reference Ref 67 with a cosine similarity of 0.65
#
# (kaynakça):  Baharı’ ve Sonrası Sürecin Analizi. Türkiye Ortadoğu Çalışmaları Dergisi, 2(2), 1-36.
# Behçet M (2019). İkinci Dünya Savaşı Sonrası Mısır’ın Siyasi Tarihi Üzerinden Arap
#
# (intext):  London: Routledge, 109-137.615
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 6 matches with Reference Ref 7 with a cosine similarity of 0.63
#
# (kaynakça):  İncelenmesi: Mısır ve İran Örnekleri. Mülkiye Dergisi , 45(3), 587-616.Bohstedt J (2014). Food Riots and the Politics of Provisions in World History. Institute of
#
# (intext):  Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 28 matches with Reference Ref 59 with a cosine similarity of 0.63
#
# (kaynakça):  Temple University Press, 3-35.
# Kamacı Y (2013). 2009’dan 2013’e Yeşil Hareket’in Yolculuğu. Uluslararası Politika
#
# (intext):  (2013).
# --------------------------------------------------------
# Reference 55 matches with Reference Ref 7 with a cosine similarity of 0.62
#
# (kaynakça):  01.05.2020.
# Scott A (1990). Ideology and The New Social Movements.  London: Unwin Hyman.
# Sinkaya B vd. (2018). İran’da Toplumsal Hareketler ve Etkileri. Göç Politikaları Merkezi ,
#
# (intext):  Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 39 matches with Reference Ref 64 with a cosine similarity of 0.61
#
# (kaynakça):  Marshall G (1999). Sosyoloji Sözlüğü . Çev. O Akınhay ve D Kömürcü, Ankara: Bilim ve
#
# (intext):  Marshall G (1999).
# --------------------------------------------------------
# Reference 8 matches with Reference Ref 39 with a cosine similarity of 0.61
#
# (kaynakça):  10(1), 119-129.
# Calhoun C (1993). ‘New Social Movements’ of the Early Nineteenth Century. Social
#
# (intext):  Calhoun C (1993).
# --------------------------------------------------------
# Reference 56 matches with Reference Ref 21 with a cosine similarity of 0.60
#
# (kaynakça):  Göç Panelleri Serisi.
# Şen G (2012). İran ve ‘Arap Baharı’: Bağlam, Söylem ve Siyaset. Ortadoğu Etütleri,  3(2),
#
# (intext):  Siyasi nedenlere bakıldığında; 603
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 10 matches with Reference Ref 40 with a cosine similarity of 0.60
#
# (kaynakça):  Castells M (1997). The Power of Identity, The Information Age: Economy, Society and
#
# (intext):  Castells M (1997).
# --------------------------------------------------------
# Reference 61 matches with Reference Ref 7 with a cosine similarity of 0.60
#
# (kaynakça):  Cambridge University Press, Third Edition.
# Tatar T (2013). Yeni Toplumsal Hareketler ve Küresel Projeler. Ortadoğu Analiz , 5(57),
#
# (intext):  Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 54 matches with Reference Ref 28 with a cosine similarity of 0.59
#
# (kaynakça):  Araştırmalar Dergisi,  18(30),  65-70.
# Sayın A (2018). İran’daki gösterilerin anatomisi. Star Açık Görüş,  6 Ocak. Erişim
#
# (intext):  2017 yılının
# sonlarında İranlı kadınlar tarafından Tahran’da başörtüsü protestosu başlatılmış
# ve bu protestolar 2018’in ilk aylarından itibaren yeni bir boyut kazanarak farklı 610
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 21 matches with Reference Ref 7 with a cosine similarity of 0.59
#
# (kaynakça):  Araştırmaları Merkezi, 21 Nisan. Son erişim tarihi, 27/04/2020.
# Fuller G E (2016).  Türkiye ve Arap Baharı.  Çev. M Acar, Ankara: Eksi Kitaplar.
# Gerbaudo P (2012). Tweets and Streets: Social Media and Contemporary Activism .
#
# (intext):  Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 60 matches with Reference Ref 7 with a cosine similarity of 0.59
#
# (kaynakça):  erişim tarihi, 27/04/2020.
# Tarrow S G. (2011). Power in Movement: Social Movements and Contentious Politics.
#
# (intext):  Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 15 matches with Reference Ref 46 with a cosine similarity of 0.59
#
# (kaynakça):  Sosyal Bilimler Dergisi,  2(13), 48-66.
# Dehghan S K (2018). Second woman arrested in Tehran for hijab protest. The
#
# (intext):  Dehghan S K (2018).
# --------------------------------------------------------
# Reference 66 matches with Reference Ref 90 with a cosine similarity of 0.58
#
# (kaynakça):  Araştırmaları Merkezi, 30 Aralık. Son erişim tarihi, 28/04/2020.
# Yanık C ve Öztürk M (2014). Toplumsal Hareketlerin Dönüşümü Üzerine Bir
#
# (intext):  Yanık C ve Öztürk M (2014).
# --------------------------------------------------------
# Reference 43 matches with Reference Ref 71 with a cosine similarity of 0.57
#
# (kaynakça):  Movement From 2000 to 2010. İçinde:  Larbi Sadiki vd. (der), Democratic Transition in
#
# (intext):  Sadiki L (2000).
# --------------------------------------------------------
# Reference 40 matches with Reference Ref 65 with a cosine similarity of 0.57
#
# (kaynakça):  Sanat Yayınları.
# Melucci A (2016). Çağdaş Hareketlerin Sembolik Meydan Okuması. İçinde: K Çayır (der),
#
# (intext):  Melucci A (2016).
# --------------------------------------------------------
# Reference 12 matches with Reference Ref 90 with a cosine similarity of 0.57
#
# (kaynakça):  Kılıç, İstanbul: Koç Üniversitesi Yayınları, Birinci Baskı.
# Çetinkaya Y D (2014). Toplumsal Hareketler. İçinde: Ş Kardaş ve A Balcı (der), Uluslararası
#
# (intext):  Yanık C ve Öztürk M (2014).
# --------------------------------------------------------
# Reference 41 matches with Reference Ref 66 with a cosine similarity of 0.57
#
# (kaynakça):  Yeni Sosyal Hareketler-Teorik Açılımlar.  İstanbul: Kaknüs Yayınları, 75-100.
# Mossallam A (2013). ’These are Liberated Territories’ – Everyday Resistance in
#
# (intext):  Mossallam A (2013).
# --------------------------------------------------------
# Reference 1 matches with Reference Ref 7 with a cosine similarity of 0.57
#
# (kaynakça):  Quarterly, Özel Sayı: Perspectives on the Arab Uprisings , 35(3), 241-254.
# Arı T (2012). Geçmişten Günümüze Ortadoğu, Siyaset, Savaş ve Diplomasi . Bursa: MKM
#
# (intext):  Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 35 matches with Reference Ref 27 with a cosine similarity of 0.56
#
# (kaynakça):  Küçükşahin E (2018). Politik Bir Fenomen Olarak Ekmek: 2008 Mısır’ında Ekmek İsyanı.
#
# (intext):  Gösterilerde 2009’daki Yeşil Hareket’in söylemlerine benzer 609
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 0 matches with Reference Ref 7 with a cosine similarity of 0.55
#
# (kaynakça):
# Aoudé I G (2013). Egypt: Revolutionary Process and Global Capitalist Crisis. Arab Studies
#
# (intext):  Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 13 matches with Reference Ref 12 with a cosine similarity of 0.55
#
# (kaynakça):  İlişkilere Giri ş. Üçüncü Baskı, İstanbul: Küre Yayınları, 479-486.
# Çolak Ç D (2016). Yeni Toplumsal Hareketlere “Yeni” Niteliği Kazandıran Özellikler
#
# (intext):  (7) Yeni toplumsal
# hareket gruplarının örgütlenmesi ve yaygınlaşması geleneksel kanalların 594
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 3 matches with Reference Ref 6 with a cosine similarity of 0.55
#
# (kaynakça):  Son erişim tarihi, 01.05.2020.
# Bekaroğlu E A ve Kurt V (2015). Mısır’da Otoriter Rejimin Sürekliliği ve Ordu: ‘Arap
#
# (intext):  Makale Gönderim Tarihi: 25.08.2020, Makale Kabul Tarihi: 20.05.2021
# Araştırma Makalesi588
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 64 matches with Reference Ref 67 with a cosine similarity of 0.54
#
# (kaynakça):  Üniversitesi Siyasal Bilimler Dergisi , 2(1), 133-144.
# Tür Ö (2009). Mısır’da Ekonomik Kalkınma Çabaları.  İstanbul Üniversitesi Siyasal Bilgiler
#
# (intext):  London: Routledge, 109-137.615
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 14 matches with Reference Ref 35 with a cosine similarity of 0.54
#
# (kaynakça):  Üzerine Bir Değerlendirme.  Sosyal  Bilimler Dergisi,  3(6), 529-537.
# Dede A (2018). Talepkâr Bir Hareket Olarak Yeni Toplumsal Hareketler. Uluslararası
#
# (intext):  Trakya Üniversitesi Sosyal Bilimler Dergisi , 21, 303-321.613
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 57 matches with Reference Ref 79 with a cosine similarity of 0.54
#
# (kaynakça):  95-118.
# Şener G (2006). Küresel Kapitalizmin Yeni Kamusal Alanı Olarak İnternet: Yeni Toplumsal
#
# (intext):  Şener G (2006).
# --------------------------------------------------------
# Reference 7 matches with Reference Ref 7 with a cosine similarity of 0.54
#
# (kaynakça):  Development Studies , 444, 1-31.
# Brecher J vd. (2002). Aşağıdan Küreselleşme . Çev. A Yıldırım vd., İstanbul: Aram Yayınları.
# Bush R (2010). Food Riots: Poverty, Power and Protest. Journal of Agrarian Change ,
#
# (intext):  Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 68 matches with Reference Ref 91 with a cosine similarity of 0.53
#
# (kaynakça):  freedom’. Son erişim tarihi,  24/04/2020.
# Yücesoy T ve Karabulut B (2019). Gündem Belirleme Kuramı Odağında İran Yeşil
#
# (intext):  Yücesoy T ve Karabulut B (2019).
# --------------------------------------------------------
# Reference 19 matches with Reference Ref 48 with a cosine similarity of 0.52
#
# (kaynakça):  Bozkurt (der),  Çağdaş Toplumsal Süreçler . Erzurum: Atatürk Üniversitesi, 1-22.
# Emin A (2017). Mısır Siyasetinde Vefd Partisi (1918-1952). (Basılmamış Yüksek Lisans
#
# (intext):  Emin A (2017).
# --------------------------------------------------------
# Reference 30 matches with Reference Ref 28 with a cosine similarity of 0.52
#
# (kaynakça):  Karabağ G (2018). İran’da başörtüsü mecburiyetine karşı “Beyaz Çarşamba” direnişleri
#
# (intext):  2017 yılının
# sonlarında İranlı kadınlar tarafından Tahran’da başörtüsü protestosu başlatılmış
# ve bu protestolar 2018’in ilk aylarından itibaren yeni bir boyut kazanarak farklı 610
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 65 matches with Reference Ref 6 with a cosine similarity of 0.51
#
# (kaynakça):  Fakültesi Dergisi,  41, 183-194.
# Türkdoğan O (1997). Sosyal Hareketlerin Sosyolojisi. İstanbul: Birleşik Yayıncılık.
# Uygur H (2017). İran’daki Protesto Gösterileri ve Sloganlar Ne Anlama Geliyor?.  İran
#
# (intext):  Makale Gönderim Tarihi: 25.08.2020, Makale Kabul Tarihi: 20.05.2021
# Araştırma Makalesi588
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 50 matches with Reference Ref 71 with a cosine similarity of 0.51
#
# (kaynakça):  Sadiki L (2000). Popular Uprisings and Arab Democratization. International Journal of
#
# (intext):  Sadiki L (2000).
# --------------------------------------------------------
# Reference 53 matches with Reference Ref 6 with a cosine similarity of 0.51
#
# (kaynakça):  26/04/2020.
# Sayın Y (2016). Arap Baharı Süreci ve Sömürgelerin Çözülmesi. KMÜ Sosyal ve Ekonomik
#
# (intext):  Makale Gönderim Tarihi: 25.08.2020, Makale Kabul Tarihi: 20.05.2021
# Araştırma Makalesi588
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 24 matches with Reference Ref 3 with a cosine similarity of 0.50
#
# (kaynakça):  Adıbelli (der), Doğu-Batı Yol Ayrımında İran.  İstanbul: Bilim+Gönül Yayınları.
# Hoffman B (2007-2008). İnternetten Demokrasi İndirmek? İnternetin Latin Amerika’da
#
# (intext):  İran’da yaşanan bu olaylar Batılı yayın organları tarafından YouTube ve Twitter
# üzerinden takip edilmiştir (Papic ve Noonan, 2011: 166).
# --------------------------------------------------------
# Reference 32 matches with Reference Ref 20 with a cosine similarity of 0.49
#
# (kaynakça):  Karagöz K. (2013). Yeni Medya Çağında Dönüşen Toplumsal Hareketler ve Dijital
#
# (intext):  Katılımcıların çeşitli yaş, cinsiyet,
# meslek, ideolojik aidiyet ve kimlik özellikleri barındırması, hareketin ortaya
# çıkışında ve yayılmasında teknolojinin kullanılması, dile getirilen taleplerin 602
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 52 matches with Reference Ref 73 with a cosine similarity of 0.49
#
# (kaynakça):  36(1), 111-129.
# Saleh H (2008). Food price crisis bites in Egypt. BBC,  3 Mayıs. Son erişim tarihi,
#
# (intext):  Saleh H (2008).
# --------------------------------------------------------
# Reference 47 matches with Reference Ref 67 with a cosine similarity of 0.49
#
# (kaynakça):  47-73.
# Özkoç Ö (2015). ‘Devrim’in Başladığı Yer: Sidi Bu Zeyd/Tunus. Mülkiye Dergisi , 39(2),
#
# (intext):  London: Routledge, 109-137.615
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 11 matches with Reference Ref 84 with a cosine similarity of 0.48
#
# (kaynakça):  Culture .  Vol 2, Oxford: Wiley-Blackwell, First Edition.
# Castells M (2001). The Internet Galaxy . New York: Oxford University Press.
# Castells M (2013). İsyan ve Umut Ağları-İnternet Çağında Toplumsal Hareketler. Çev. E
#
# (intext):  Mülkiye Dergisi , 45(3), 587-616.Tilly C (2004).
# --------------------------------------------------------
# Reference 70 matches with Reference Ref 68 with a cosine similarity of 0.48
#
# (kaynakça):  9(2), 22-47.
#
# (intext):  Mülkiye Dergisi , 45(3), 587-616.Offe C (2016).
# --------------------------------------------------------
# Reference 67 matches with Reference Ref 53 with a cosine similarity of 0.48
#
# (kaynakça):  Değerlendirme. Mukaddime,  5(1), 45-63.
# YouTube (11/02/2011). CNN: Egyptian activist, Wael Ghonim ‘Facebook to thank for
#
# (intext):  Mülkiye Dergisi , 45(3), 587-616.Gerbaudo P (2014).
# --------------------------------------------------------
# Reference 33 matches with Reference Ref 6 with a cosine similarity of 0.48
#
# (kaynakça):  Aktivizm Hareketleri. İletişim ve Diplomasi, 1(1), 131-156.
# Koç M (2017). İran’da Üniversiteler ve Siyaset. İran Araştırmaları Merkezi,  13 Kasım.
#
# (intext):  Makale Gönderim Tarihi: 25.08.2020, Makale Kabul Tarihi: 20.05.2021
# Araştırma Makalesi588
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 36 matches with Reference Ref 62 with a cosine similarity of 0.47
#
# (kaynakça):  Contemporary Research in Economics and Social Sciences , 2(2), 317-347.
# Laclau E ve Mouffe C (2001). Hegemony and Socialist Strategy: Towards a Radical
#
# (intext):  Laclau E ve Mouffe C (2001).
# --------------------------------------------------------
# Reference 9 matches with Reference Ref 68 with a cosine similarity of 0.47
#
# (kaynakça):  Science History , 17(3), 385-427.
#
# (intext):  Mülkiye Dergisi , 45(3), 587-616.Offe C (2016).
# --------------------------------------------------------
# Reference 20 matches with Reference Ref 6 with a cosine similarity of 0.47
#
# (kaynakça):  Tezi). İstanbul: Fatih Sultan  Mehmet Vakıf Üniversitesi.
# Erginbaş E (2020). İran’da Toplumsal Hareketler Bağlamında ‘Öteki Olmak’. İran
#
# (intext):  Makale Gönderim Tarihi: 25.08.2020, Makale Kabul Tarihi: 20.05.2021
# Araştırma Makalesi588
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 17 matches with Reference Ref 28 with a cosine similarity of 0.47
#
# (kaynakça):  erişim tarihi, 27/04/2020.
# Deutsche Welle (01/02/2018). İranlı kadınların başörtüsü eylemi yayılıyor. Son erişim
#
# (intext):  2017 yılının
# sonlarında İranlı kadınlar tarafından Tahran’da başörtüsü protestosu başlatılmış
# ve bu protestolar 2018’in ilk aylarından itibaren yeni bir boyut kazanarak farklı 610
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 27 matches with Reference Ref 7 with a cosine similarity of 0.45
#
# (kaynakça):  Johnston vd. (der), New Social Movements: From Ideology to Identity. Philadelphia:
#
# (intext):  Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 69 matches with Reference Ref 96 with a cosine similarity of 0.45
#
# (kaynakça):  Devrimine Bakış: Tweetler Üzerinden Bir Analiz. Karadeniz İletişim Araştırmaları Dergisi ,
#
# (intext):  Gusfield (1994: 6-8) yeni toplumsal
# hareketlerin karakteristik özelliklerini 8 madde ile özetlemiştir.
# --------------------------------------------------------
# Reference 46 matches with Reference Ref 35 with a cosine similarity of 0.45
#
# (kaynakça):  İçinde: K Çayır (der), Yeni Sosyal Hareketler-Teorik Açılımlar.  İstanbul: Kaknüs Yayınları,
#
# (intext):  Trakya Üniversitesi Sosyal Bilimler Dergisi , 21, 303-321.613
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 26 matches with Reference Ref 84 with a cosine similarity of 0.45
#
# (kaynakça):  97-113.
# Johnston H vd. (1994). Identities, Grievances and New Social Movements. İçinde: Hank
#
# (intext):  Mülkiye Dergisi , 45(3), 587-616.Tilly C (2004).
# --------------------------------------------------------
# Reference 51 matches with Reference Ref 72 with a cosine similarity of 0.45
#
# (kaynakça):  Middle East Studies , 32(1),  71-95.
# Salamey I (2015). Post-Arab Spring: Changes and Challenges. Third World Quarterly,
#
# (intext):  Salamey I (2015).
# --------------------------------------------------------
# Reference 37 matches with Reference Ref 7 with a cosine similarity of 0.44
#
# (kaynakça):  Democratic Politics.  London, New  York: Verso, Second Edition.
# Lomas N (2018). Telegram and Instagram being restricted in Iran.  Techcrunch,  2 Ocak.
#
# (intext):  Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 2 matches with Reference Ref 28 with a cosine similarity of 0.44
#
# (kaynakça):  Yayıncılık.
# BBC Türkçe (02/02/2018). İran’da ‘başörtüsünü çıkarma’ eylemleri: 29 kadın gözaltında.
#
# (intext):  2017 yılının
# sonlarında İranlı kadınlar tarafından Tahran’da başörtüsü protestosu başlatılmış
# ve bu protestolar 2018’in ilk aylarından itibaren yeni bir boyut kazanarak farklı 610
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 59 matches with Reference Ref 80 with a cosine similarity of 0.44
#
# (kaynakça):  Üniversitesi.
# Tafiş A (2013). İran’daki Yeşil Hareket: Gerçeği ve akıbeti. Aljazeera Türk , 30 Aralık. Son
#
# (intext):  Tafiş A (2013).
# --------------------------------------------------------
# Reference 42 matches with Reference Ref 7 with a cosine similarity of 0.43
#
# (kaynakça):  Egypt: Dismantling State Power,  Experimenting with Alternatives and the Growing
#
# (intext):  Keywords: New Social Movements, Egypt, Iran, Bread Riot, Green Movement.589
# Tandoğan Ş M (2021) Yeni Paradigma Bağlamında Ortadoğu’daki Toplumsal Hareketlerin
# İncelenmesi: Mısır ve İran Örnekleri.
# --------------------------------------------------------
# Reference 16 matches with Reference Ref 31 with a cosine similarity of 0.39
#
# (kaynakça):  Guardian , 29 Ocak. Son erişim tarihi, 01/05/2020.
# Deutsche Welle (29/12/2017). İran’da hükümet karşıtı gösteriler devam ediyor. Son
#
# (intext):  https://
# www.bbc.com/turkce/haberler-dunya-42916446 Son erişim tarihi, 01/05/2020
# Kaynakça
# Aoudé I G (2013).
# --------------------------------------------------------
# Reference 29 matches with Reference Ref 31 with a cosine similarity of 0.39
#
# (kaynakça):  Akademisi, 1 Temmuz. Son erişim tarihi, 27/04/2020.
#
# (intext):  https://
# www.bbc.com/turkce/haberler-dunya-42916446 Son erişim tarihi, 01/05/2020
# Kaynakça
# Aoudé I G (2013).
# --------------------------------------------------------
# Reference 31 matches with Reference Ref 77 with a cosine similarity of 0.37
#
# (kaynakça):  devam ediyor. Medyascope , 30 Ocak. Son erişim tarihi: 01/05/2020.
#
# (intext):  (2018).
# --------------------------------------------------------
# Reference 34 matches with Reference Ref 59 with a cosine similarity of 0.37
#
# (kaynakça):  Son erişim tarihi, 28/04/2020.
#
# (intext):  (2013).
# --------------------------------------------------------
# Reference 38 matches with Reference Ref 59 with a cosine similarity of 0.37
#
# (kaynakça):  Son erişim tarihi, 28/04/2020.
#
# (intext):  (2013).
# --------------------------------------------------------
# Reference 49 matches with Reference Ref 31 with a cosine similarity of 0.34
#
# (kaynakça):  Kütüphaneciliği, 25(1), 165-172.
# Sabah (12/07/1999). Tabular yıkıldı. Son erişim tarihi, 28/04/2020.
#
# (intext):  https://
# www.bbc.com/turkce/haberler-dunya-42916446 Son erişim tarihi, 01/05/2020
# Kaynakça
# Aoudé I G (2013).
# --------------------------------------------------------
# Reference 58 matches with Reference Ref 31 with a cosine similarity of 0.33
#
# (kaynakça):  Hareketlerin İnterneti Kullanımı. (Basılmamış Doktora Tezi). İstanbul: Marmara
#
# (intext):  https://
# www.bbc.com/turkce/haberler-dunya-42916446 Son erişim tarihi, 01/05/2020
# Kaynakça
# Aoudé I G (2013).
# --------------------------------------------------------
# Reference 25 matches with Reference Ref 94 with a cosine similarity of 0.31
#
# (kaynakça):  Vatandaşlık Haklarını İlerletme Potansiyeli ve Sınırlamaları. Uluslararası İlişkiler,  4(16),
#
# (intext):  Toplumsal hareketlerin oluşmasına
# giden süreç Brecher, Costello ve Smith (2002: 42-43) tarafından; “var olan ve
# genellikle belirli toplumsal grupları etkileyen toplumsal sorunların zamanla
# birikmesi ile başlayan ve zaman içinde başkalarının da aynı sorunlara işaret
# ettiğinin fark edilmesiyle gelişen bir süreç” şeklinde ifade edilmiştir.
# --------------------------------------------------------
